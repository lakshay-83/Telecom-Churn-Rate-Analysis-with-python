# %%
import numpy as np
import pandas as pd

pd.set_option("display.precision", 2)

# %%
df=pd.read_csv('churn.csv')
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df.shape
# Out:
# (667, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.tail(4)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 663                     29               83.6              131
# 664                      0              193.9              118
# 665                      0              169.8              114
# 666                      0              213.8              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 663             14.21              203.9              131             17.33
# 664             32.96               85.0              110              7.23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %% [markdown]
#  Changing churn from logical(bool) to integer

# %%
df["Churn"] = df["Churn"].astype("int64")

# %%
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count          667.00     667.00                 667.00             667.00
# mean           102.84     436.16                   8.41             180.95
# std             40.82      41.78                  13.99              55.51
# min              1.00     408.00                   0.00              25.90
# 25%             76.00     408.00                   0.00             146.25
# 50%            102.00     415.00                   0.00             178.30
# 75%            128.00     415.00                  20.00             220.70
# max            232.00     510.00                  51.00             334.30
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count           667.00            667.00             667.00           667.00
# mean            100.94             30.76             203.36           100.48
# ...

# %% [markdown]
# In order to see statistics on non-numerical features, explicitly indicating data types of interest in the include parameter.

# %%
df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan
# count    667                667             667
# unique    51                  2               2
# top       AZ                 No              No
# freq      19                614             478

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    572
# 1     95
# Name: count, dtype: int64

# %% [markdown]
# 2850 users out of 3333 are loyal; their Churn value is 0. To calculate fractions, passing normalize=True to the value_counts function.

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# 0    0.86
# 1    0.14
# Name: proportion, dtype: float64

# %% [markdown]
# Sorting the data frame by one of the variables

# %%
df.sort_values(by='Total day charge', ascending=False)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 203    DE             129        510                 No              No
# 2      NY             161        415                 No              No
# 35     TX             208        510                 No              No
# 549    OR              81        415                 No              No
# 175    SC              87        408                 No              No
# ..    ...             ...        ...                ...             ...
# 537    DC              80        408                 No              No
# 594    VA             113        408                 No             Yes
# 103    NJ              95        415                 No             Yes
# 241    PA             122        415                 No              No
# 224    WY              53        415                 No             Yes
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.sort_values(by=["Churn", "Total day charge"], ascending=[True, False]).head(5)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 146    MN              13        510                 No             Yes
# 104    LA              67        510                 No              No
# 636    DC              93        408                 No             Yes
# 177    FL             144        415                 No             Yes
# 340    CT              95        415                 No             Yes
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 146                     21              315.6              105
# 104                      0              310.4               97
# 636                     22              306.2              123
# 177                     51              283.9               98
# 340                     36              283.1              112
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# Indexing and retriving data

# %%
df["Churn"].mean()
# Out:
# 0.1424287856071964

# %% [markdown]
# Above value represent 14.5% churn rate which is quite high for a company

# %% [markdown]
# What are average values of numerical features for churned users?

# %%
df[df["Churn"] == 1].describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count           95.00      95.00                  95.00              95.00
# mean           104.07     438.94                   4.89             213.99
# std             36.56      43.95                  11.85              70.96
# min             29.00     408.00                   0.00              62.60
# 25%             79.50     408.00                   0.00             154.10
# 50%            102.00     415.00                   0.00             231.20
# 75%            126.50     510.00                   0.00             270.50
# max            209.00     510.00                  48.00             334.30
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count            95.00             95.00              95.00            95.00
# mean            101.91             36.38             224.76           103.06
# ...

# %% [markdown]
# How much time (on average) do churned users spend on the phone during daytime?

# %%
df[df["Churn"] == 1]['Total day minutes'].mean()
# Out:
# 213.9915789473684

# %% [markdown]
# What is the maximum length of international calls among loyal users (Churn == 0) who do not have an international plan?

# %%
df[(df['Churn']==0) & (df['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 18.0

# %%
df.loc[0:5, 'State':'Area code']
# Out:
#   State  Account length  Area code
# 0    LA             117        408
# 1    IN              65        415
# 2    NY             161        415
# 3    SC             111        415
# 4    HI              49        510
# 5    AK              36        408

# %% [markdown]
# Applying Functions to Cells, Columns and Rows

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              232
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         334.3
# Total day calls             165
# Total day charge          56.83
# Total eve minutes         361.8
# Total eve calls             168
# Total eve charge          30.75
# Total night minutes       367.7
# Total night calls           175
# Total night charge        16.55
# Total intl minutes         18.3
# Total intl calls             18
# Total intl charge          4.94
# Customer service calls        8
# Churn                         1
# dtype: object

# %% [markdown]
# The apply method can also be used to apply a function to each row. To do this, specify axis=1 and use lambda function

# %%
df[df['State'].apply(lambda State:State[0]=='W')].head()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 9      WI              68        415                 No              No
# 24     WA             127        408                 No              No
# 42     WY             215        510                 No              No
# 51     WA              83        415                 No              No
# 109    WI              69        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 9                        0              148.8               70
# 24                       0              146.7               91
# 42                       0               83.6              148
# 51                       0              221.4              103
# 109                      0              279.8               90
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# The map method can be used to replace values in a column by passing a dictionary of the form {old_value: new_value} as its argument

# %%
d = {"No": False, "Yes": True}
df["International plan"] = df["International plan"].map(d)
b = {"No": 0, "Yes": 1}
df["Voice mail plan"] = df["Voice mail plan"].map(b)
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    LA             117        408               False                0
# 1    IN              65        415               False                0
# 2    NY             161        415               False                0
# 3    SC             111        415               False                0
# 4    HI              49        510               False                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df['Voice mail plan'].value_counts()
# Out:
# Voice mail plan
# 0    478
# 1    189
# Name: count, dtype: int64

# %% [markdown]
# Same map function is used to replace voice mail plan values

# %%
a = {0: False, 1: True}
df = df.replace({"Voice mail plan": a})
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    LA             117        408               False            False
# 1    IN              65        415               False            False
# 2    NY             161        415               False            False
# 3    SC             111        415               False            False
# 4    HI              49        510               False            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %% [markdown]
# Grouping the values by using group by function

# %%
columns_to_show = ["Total day minutes", "Total eve minutes", "Total night minutes"]

df.groupby(["Voice mail plan"])[columns_to_show].describe(percentiles=[])
# Out:
#                 Total day minutes                                     \
#                             count    mean    std   min    50%    max
# Voice mail plan
# False                       478.0  183.06  55.65  35.1  178.8  334.3
# True                        189.0  175.60  54.94  25.9  175.4  315.6
#
#                 Total eve minutes                                      \
#                             count    mean    std   min     50%    max
# Voice mail plan
# False                       478.0  202.40  50.59  48.1  202.75  351.6
# True                        189.0  205.76  47.49  75.9  206.00  361.8
#
#                 Total night minutes
#                               count    mean    std   min     50%    max
# Voice mail plan
# False                         478.0  198.85  49.51  61.4  199.65  367.7
# True                          189.0  201.80  50.45  23.2  204.00  345.8

# %%
df.shape
# Out:
# (667, 20)

# %% [markdown]
# Let’s do the same thing, but slightly differently by passing a list of functions to agg()

# %%
columns_to_show = ["Total day minutes", "Total eve minutes", "Total night minutes"]

df.groupby(["Churn"])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7088\2409454345.py:3: FutureWarning: The provided callable <function mean at 0x0000015C4D86C180> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(["Churn"])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# C:\Users\hp\AppData\Local\Temp\ipykernel_7088\2409454345.py:3: FutureWarning: The provided callable <function std at 0x0000015C4D86C2C0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby(["Churn"])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    LA             117        408               False            False
# 1    IN              65        415               False            False
# 2    NY             161        415               False            False
# 3    SC             111        415               False            False
# 4    HI              49        510               False            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df['International plan'].describe()
# Out:
# count       667
# unique        2
# top       False
# freq        614
# Name: International plan, dtype: object

# %%
df["Churn"] = df["Churn"].astype("int64")
df['International plan'].describe()
# Out:
# count       667
# unique        2
# top       False
# freq        614
# Name: International plan, dtype: object

# %%
d = {"No": 0, "Yes": 1}
df["International plan"] = df["International plan"].map(d)
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    LA             117        408                 NaN            False
# 1    IN              65        415                 NaN            False
# 2    NY             161        415                 NaN            False
# 3    SC             111        415                 NaN            False
# 4    HI              49        510                 NaN            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %% [markdown]
# Creating summary Tables

# %% [markdown]
# Building a contingency table using the crosstab method to see the relationship between two variables

# %%
pd.crosstab(df['Churn'],df['International plan'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.crosstab(df['Churn'],df['Voice mail plan'],normalize=True)
# Out:
# Voice mail plan  False  True
# Churn
# 0                 0.60   0.26
# 1                 0.12   0.02

# %% [markdown]
# We can see that most of the users are loyal and do not use additional services (International Plan/Voice mail)

# %% [markdown]
# looking at the average number of day, evening, and night calls by area code

# %%
df.pivot_table(
    ["Total day calls", "Total eve calls", "Total night calls"],
    ["Area code"],
    aggfunc="mean",
)
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408                  99.39           100.68             100.95
# 415                 101.93           100.07              99.02
# 510                 100.48           101.11             101.52

# %% [markdown]
# Adding columns to the dataframe

# %%
df["Total charge"] = (
    df["Total day charge"]
    + df["Total eve charge"]
    + df["Total night charge"]
    + df["Total intl charge"]
)
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    LA             117        408                 NaN            False
# 1    IN              65        415                 NaN            False
# 2    NY             161        415                 NaN            False
# 3    SC             111        415                 NaN            False
# 4    HI              49        510                 NaN            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             31.37              351.6  ...             29.89
# ...

# %%
df["Total calls"] = (
    df["Total day calls"]
    + df["Total eve calls"]
    + df["Total night calls"]
    + df["Total intl calls"]
)
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    LA             117        408                 NaN            False
# 1    IN              65        415                 NaN            False
# 2    NY             161        415                 NaN            False
# 3    SC             111        415                 NaN            False
# 4    HI              49        510                 NaN            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             31.37              351.6  ...                215.8
# ...

# %%
df
# Out:
#     State  Account length  Area code  International plan  Voice mail plan  \
# 0      LA             117        408                 NaN            False
# 1      IN              65        415                 NaN            False
# 2      NY             161        415                 NaN            False
# 3      SC             111        415                 NaN            False
# 4      HI              49        510                 NaN            False
# ..    ...             ...        ...                 ...              ...
# 662    WI             114        415                 NaN             True
# 663    AL             106        408                 NaN             True
# 664    VT              60        415                 NaN            False
# 665    WV             159        415                 NaN            False
# 666    CT             184        510                 NaN            False
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# Attempt at predicting telecom churn

# %%
pd.crosstab(df["Churn"], df["International plan"], margins=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# some imports to set up plotting
import matplotlib.pyplot as plt
# pip install seaborn
import seaborn as sns

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x="International plan", hue="Churn", data=df);

# %% [markdown]
# We see that, with International Plan, the churn rate is much higher

# %%
pd.crosstab(df["Churn"], df["Customer service calls"], margins=True)
# Out:
# Customer service calls    0    1    2   3   4   5  6  7  8  All
# Churn
# 0                       129  213  126  74  21   6  1  1  1  572
# 1                        13   23   25   7  12  11  4  0  0   95
# All                     142  236  151  81  33  17  5  1  1  667

# %%
sns.countplot(x="Customer service calls", hue="Churn", data=df);

# %% [markdown]
# Although it's not so obvious from the summary table, it's easy to see from the above plot that the churn rate increases sharply from 4 customer service calls and above.

# %%
df["Many_service_calls"] = (df["Customer service calls"] > 3).astype("int")

pd.crosstab(df["Many_service_calls"], df["Churn"], margins=True)
# Out:
# Churn                 0   1  All
# Many_service_calls
# 0                   542  68  610
# 1                    30  27   57
# All                 572  95  667

# %%
sns.countplot(x="Many_service_calls", hue="Churn", data=df);

# %%
pd.crosstab(df["Many_service_calls"] & df["International plan"], df["Churn"])
# Out:
# Churn    0   1
# row_0
# False  572  95

# %% [markdown]
# predicting that a customer is not loyal (Churn=1) in the case when the number of calls to the service center is greater than 3 and the International Plan is added (and predicting Churn=0 otherwise), we might expect an accuracy of 85.8% (we are mistaken only 464 + 9 times). This number, 85.8%, that we got through this very simple reasoning serves as a good starting point (baseline) for the further machine learning models
